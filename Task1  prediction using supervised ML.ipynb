# %% [markdown]
# ##GRIP : THE SPARK FOUNDATION
#
# ## Linear Regression with Python Scikit Learn
#
# In this section we will see how the Python Scikit-Learn library for machine learning can be used to implement regression functions. We will start with simple linear regression involving two variables.
#
# ## Simple Linear Regression
#
# In this regression task we will predict the percentage of marks that a student is expected to score based upon the number of hours they studied.
#
# #### What will be predicted score if a student studies for 9.25 hrs/ day?

# %% [markdown]
# ## Author: KAMAL PAREKH

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading data from remote link 
url = "http://bit.ly/w-data"
data = pd.read_csv(url)
data.head(5)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# **Let's plot our data points on 2-D graph to eyeball our dataset and see if we can manually find any relationship between the data. We can create the plot with the following script:

# %%
plt.scatter(data['Hours'],data['Scores'])
plt.xlabel('Studied Hours')
plt.ylabel('Percentage Scores')
plt.title("HOURES vs SCORES")
plt.grid()

# %%
x = data.Hours
x.head()
# Out:
# 0    2.5
# 1    5.1
# 2    3.2
# 3    8.5
# 4    3.5
# Name: Hours, dtype: float64

# %%
y = data.Scores
y.head()
# Out:
# 0    21
# 1    47
# 2    27
# 3    75
# 4    30
# Name: Scores, dtype: int64

# %%
y= y.reshape(-1,1)
y.ndim
# Out:
# 2

# %%
y.shape
# Out:
# (25, 1)

# %% [markdown]
# **It show clearly that there is positive linear relation betw HOURS STUDIED VS SCORES

# %% [markdown]
# # feathure and  target

# %%
x = data['Hours']
x
# Out:
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4
# 20    2.7
# 21    4.8
# 22    3.8
# 23    6.9
# 24    7.8
# Name: Hours, dtype: float64

# %%
x = x.reshape(-1,1)
x.ndim
# Out:
# 2

# %%
y = data['Scores']

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(np.array(data['Hours']).reshape(-1, 1),  
                                                 np.array(data.Scores).reshape(-1, 1),
                                                 test_size = 0.2,
                                                 random_state = 0)

# %%
X_test.shape, y_test.shape
# Out:
# ((5, 1), (5, 1))

# %%
X_train.shape, y_train.shape
# Out:
# ((20, 1), (20, 1))

# %% [markdown]
# # linear regression model

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([[9.91065648]])

# %%
line
# Out:
# 0     26.794801
# 1     52.562508
# 2     33.732261
# 3     86.258740
# 4     36.705458
# 5     16.884145
# 6     93.196200
# 7     56.526771
# 8     84.276609
# 9     28.776933
# 10    78.330215
# 11    60.491033
# 12    46.616114
# 13    34.723326
# 14    12.919882
# 15    90.223003
# 16    26.794801
# 17    20.848407
# 18    62.473165
# 19    75.357018
# 20    28.776933
# 21    49.589311
# 22    39.678655
# 23    70.401690
# 24    79.321281
# Name: Hours, dtype: float64

# %%
# now plotting the regression line 
y_pred = reg.coef_[0]*x + reg.intercept_[0]
plt.scatter(data['Hours'],data['Scores'])
plt.plot(x, y_pred, c='r')
plt.show()

# %%
y_pred =  reg.predict(X_test) 
y_pred, y_pred.shape
# Out:
# (array([[16.88414476],
#         [33.73226078],
#         [75.357018  ],
#         [26.79480124],
#         [60.49103328]]), (5, 1))

# %%
data = pd.DataFrame({'Actual scores': y_test.reshape(5,), 
                     'Predicted_score': y_pred.reshape(5,)})
data
# Out:
#    Actual scores  Predicted_score
# 0             20        16.884145
# 1             27        33.732261
# 2             69        75.357018
# 3             30        26.794801
# 4             62        60.491033

# %%
hours = 9.23
pred = reg.predict([[hours]])
print("no.of study hours:",hours)
print("predicted marks are :",pred)
# Out:
# no.of study hours: 9.23
# predicted marks are : [[93.49351936]]

# %%
y_test
# Out:
# array([[20],
#        [27],
#        [69],
#        [30],
#        [62]])

# %% [markdown]
# **here we have measure accuracy of percentage scores**

# %%
reg.score(X_test, y_test)
# Out:
# 0.9454906892105354

# %% [markdown]
# **here the accuracy comes 94%**
